# %% [markdown]
# # Applying Generative Models for Data Augmentation in Data Mining

# %%
# !pip install sdv
# Out:
# Requirement already satisfied: sdv in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (1.35.0)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (1.42.75)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (1.42.75)
# Requirement already satisfied: cloudpickle>=2.1.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (3.1.2)
# Requirement already satisfied: graphviz>=0.13.2 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (0.21)
# Requirement already satisfied: numpy>=1.24.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (2.3.5)
# Requirement already satisfied: pandas<3,>=1.5.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (2.3.3)
# Requirement already satisfied: tqdm>=4.29 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (4.67.3)
# Requirement already satisfied: copulas>=0.12.1 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (0.14.1)
# Requirement already satisfied: ctgan>=0.11.1 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (0.12.1)
# Requirement already satisfied: deepecho>=0.7.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (0.8.1)
# Requirement already satisfied: rdt>=1.18.2 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (1.20.0)
# Requirement already satisfied: sdmetrics>=0.28.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (0.28.0)
# Requirement already satisfied: platformdirs>=4.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (4.9.4)
# Requirement already satisfied: pyyaml>=6.0.1 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sdv) (6.0.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from boto3<2.0.0,>=1.28->sdv) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from boto3<2.0.0,>=1.28->sdv) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from botocore<2.0.0,>=1.31->sdv) (2.6.3)
# Requirement already satisfied: pytz>=2020.1 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from pandas<3,>=1.5.0->sdv) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from pandas<3,>=1.5.0->sdv) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: plotly>=5.10.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from copulas>=0.12.1->sdv) (6.6.0)
# Requirement already satisfied: scipy>=1.9.2 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from copulas>=0.12.1->sdv) (1.16.3)
# Requirement already satisfied: torch>=2.0.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from ctgan>=0.11.1->sdv) (2.11.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (2.18.1)
# Requirement already satisfied: packaging in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: scikit-learn>=1.1.3 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from rdt>=1.18.2->sdv) (1.8.0)
# Requirement already satisfied: Faker!=37.11.0,>=17 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from rdt>=1.18.2->sdv) (40.11.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from scikit-learn>=1.1.3->rdt>=1.18.2->sdv) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from scikit-learn>=1.1.3->rdt>=1.18.2->sdv) (3.6.0)
# Requirement already satisfied: filelock in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (3.6.1)
# Requirement already satisfied: jinja2 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (2026.2.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->ctgan>=0.11.1->sdv) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.0.0->ctgan>=0.11.1->sdv) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->ctgan>=0.11.1->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.1->sdv) (2.1.5)

# %%
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
import pandas as pd

# %%
# Load your dataset
df = pd.read_csv('titanic.csv')
df = df[['Pclass', 'Sex', 'Age', 'Fare', 'SibSp', 'Parch']].dropna()
df['Sex'] = df['Sex'].astype(str)

# Define metadata
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(df)

# Train CTGAN
model = CTGANSynthesizer(metadata)
model.fit(df)

# Generate synthetic data
synthetic_data = model.sample(1000)
print(synthetic_data.head())
# Out:
# /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages/sdv/single_table/base.py:178: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /home/ridhwanlaptop/miniconda3/envs/mlenv/lib/python3.11/site-packages/sdv/single_table/base.py:134: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
#    Pclass     Sex    Age     Fare  SibSp  Parch
# 0       3    male  14.60  20.5615      1      0
# 1       2    male  37.90  63.5084      5      0
# 2       3  female  23.42  50.6837      1      2
# 3       3    male   6.93  55.2315      0      0
# 4       3    male  45.25  55.0252      2      1
